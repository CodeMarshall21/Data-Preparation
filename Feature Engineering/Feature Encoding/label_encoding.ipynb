# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = {
    "Item": ["Shirt", "Jeans", "Jacket", "Jeans", "Shirt"],
    "Color": ["Red", "Blue", "Green", "Blue", "Red"],
    "Size": ["S", "M", "L", "M", "S"],
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Item  Color Size
# 0   Shirt    Red    S
# 1   Jeans   Blue    M
# 2  Jacket  Green    L
# 3   Jeans   Blue    M
# 4   Shirt    Red    S

# %%
encoder = LabelEncoder()

# %%
df["Encoded_Size"] = encoder.fit_transform(df["Size"])
df
# Out:
#      Item  Color Size  Encoded_Size
# 0   Shirt    Red    S             2
# 1   Jeans   Blue    M             1
# 2  Jacket  Green    L             0
# 3   Jeans   Blue    M             1
# 4   Shirt    Red    S             2

# %%
df["Encoded_Color"] = encoder.fit_transform(df["Color"])
df
# Out:
#      Item  Color Size  Encoded_Size  Encoded_Color
# 0   Shirt    Red    S             2              2
# 1   Jeans   Blue    M             1              0
# 2  Jacket  Green    L             0              1
# 3   Jeans   Blue    M             1              0
# 4   Shirt    Red    S             2              2
